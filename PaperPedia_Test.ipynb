# %% [markdown]
# # DATA PROCESSING

# %% [markdown]
# # 1. Checking descriptive statistics of the dataset.

# %% [markdown]
#     As per checking of the 'train.csv' and 'test.csv'
#         import helped in importing the libraries
#         pandas is used for working with huge data-sets
#         numpy is used for high-level mathematical calculation over arrays of data
#         seaborn is used for making statistical graphics
#         matplotlib.pyplot is used for creating figures and visualization of data

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt 
from matplotlib.pyplot import pie, axis, show
# %matplotlib inline

# %% [markdown]
# # a) Checking in which directory We're working

# %% [markdown]
#     import os lets the user interact with Native OS, Python is running on
#     where os.getcwd means get current working directory we're working on

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\user\\Desktop\\PaperPedia'

# %% [markdown]
# # b) Loading the datasets

# %% [markdown]
#     By implementing the below commands we're loading the dataset into given variable names as 'dataset1' and 'dataset2'

# %%
dataset1 = pd.read_csv('train.csv')
dataset2 = pd.read_csv('test.csv')

# %% [markdown]
# # c) Reading both the datasets

# %%
dataset1
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 550063  1006033  P00372445      M  51-55          13             B
# 550064  1006035  P00375436      F  26-35           1             C
# 550065  1006036  P00375436      F  26-35          15             B
# 550066  1006038  P00375436      F    55+           1             C
# 550067  1006039  P00371644      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %%
dataset2
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000004  P00128942      M  46-50           7             B
# 1       1000009  P00113442      M  26-35          17             C
# 2       1000010  P00288442      F  36-45           1             B
# 3       1000010  P00145342      F  36-45           1             B
# 4       1000011  P00053842      F  26-35           1             C
# ...         ...        ...    ...    ...         ...           ...
# 233594  1006036  P00118942      F  26-35          15             B
# 233595  1006036  P00254642      F  26-35          15             B
# 233596  1006036  P00031842      F  26-35          15             B
# 233597  1006037  P00124742      F  46-50           1             C
# 233598  1006039  P00316642      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               1                   1
# ...

# %% [markdown]
# # d) Describing the dataset1

# %% [markdown]
#         describe() funtion is only applied on integer and float values not on object datatype.

# %%
dataset1.describe()
# Out:
#             User_ID     Occupation  Marital_Status  Product_Category_1  \
# count  5.500680e+05  550068.000000   550068.000000       550068.000000
# mean   1.003029e+06       8.076707        0.409653            5.404270
# std    1.727592e+03       6.522660        0.491770            3.936211
# min    1.000001e+06       0.000000        0.000000            1.000000
# 25%    1.001516e+06       2.000000        0.000000            1.000000
# 50%    1.003077e+06       7.000000        0.000000            5.000000
# 75%    1.004478e+06      14.000000        1.000000            8.000000
# max    1.006040e+06      20.000000        1.000000           20.000000
#
#        Product_Category_2  Product_Category_3       Purchase
# count       376430.000000       166821.000000  550068.000000
# mean             9.842329           12.668243    9263.968713
# std              5.086590            4.125338    5023.065394
# min              2.000000            3.000000      12.000000
# ...

# %% [markdown]
#         To apply describe() function on object datatype we will write below command

# %%
dataset1.describe(include=['object'])
# Out:
#        Product_ID  Gender     Age City_Category Stay_In_Current_City_Years
# count      550068  550068  550068        550068                     550068
# unique       3631       2       7             3                          5
# top     P00265242       M   26-35             B                          1
# freq         1880  414259  219587        231173                     193821

# %% [markdown]
# # e) Conting the values of dataset1

# %% [markdown]
#         For counting User_ID of dataset1 value_counts() function is used to give the total of it

# %%
dataset1['User_ID'].value_counts()
# Out:
# 1001680    1026
# 1004277     979
# 1001941     898
# 1001181     862
# 1000889     823
#            ...
# 1002690       7
# 1002111       7
# 1005810       7
# 1004991       7
# 1000708       6
# Name: User_ID, Length: 5891, dtype: int64

# %% [markdown]
#         Converting above series into dataframe

# %%
dataset1['User_ID'].value_counts().to_frame()
# Out:
#          User_ID
# 1001680     1026
# 1004277      979
# 1001941      898
# 1001181      862
# 1000889      823
# ...          ...
# 1002690        7
# 1002111        7
# 1005810        7
# 1004991        7
# 1000708        6
#
# [5891 rows x 1 columns]

# %% [markdown]
#         Counting Product_ID of dataset1

# %%
dataset1['Product_ID'].value_counts()
# Out:
# P00265242    1880
# P00025442    1615
# P00110742    1612
# P00112142    1562
# P00057642    1470
#              ...
# P00314842       1
# P00298842       1
# P00231642       1
# P00204442       1
# P00066342       1
# Name: Product_ID, Length: 3631, dtype: int64

# %% [markdown]
#         Converting above series into dataframe

# %%
dataset1['Product_ID'].value_counts().to_frame()
# Out:
#            Product_ID
# P00265242        1880
# P00025442        1615
# P00110742        1612
# P00112142        1562
# P00057642        1470
# ...               ...
# P00314842           1
# P00298842           1
# P00231642           1
# P00204442           1
# P00066342           1
#
# [3631 rows x 1 columns]

# %% [markdown]
#         Counting Gender of dataset1

# %%
dataset1['Gender'].value_counts()
# Out:
# M    414259
# F    135809
# Name: Gender, dtype: int64

# %% [markdown]
#         Converting above series into dataframe

# %%
dataset1['Gender'].value_counts().to_frame()
# Out:
#    Gender
# M  414259
# F  135809

# %% [markdown]
#         Counting Age of dataset1

# %%
dataset1['Age'].value_counts()
# Out:
# 26-35    219587
# 36-45    110013
# 18-25     99660
# 46-50     45701
# 51-55     38501
# 55+       21504
# 0-17      15102
# Name: Age, dtype: int64

# %% [markdown]
#         Converting above series into dataframe

# %%
dataset1['Age'].value_counts().to_frame()
# Out:
#           Age
# 26-35  219587
# 36-45  110013
# 18-25   99660
# 46-50   45701
# 51-55   38501
# 55+     21504
# 0-17    15102

# %% [markdown]
#         Counting Occupation of dataset1

# %%
dataset1['Occupation'].value_counts()
# Out:
# 4     72308
# 0     69638
# 7     59133
# 1     47426
# 17    40043
# 20    33562
# 12    31179
# 14    27309
# 2     26588
# 16    25371
# 6     20355
# 3     17650
# 10    12930
# 5     12177
# 15    12165
# 11    11586
# 19     8461
# 13     7728
# 18     6622
# 9      6291
# 8      1546
# Name: Occupation, dtype: int64

# %% [markdown]
#         Converting above series into dataframe

# %%
dataset1['Occupation'].value_counts().to_frame()
# Out:
#     Occupation
# 4        72308
# 0        69638
# 7        59133
# 1        47426
# 17       40043
# 20       33562
# 12       31179
# 14       27309
# 2        26588
# 16       25371
# 6        20355
# 3        17650
# 10       12930
# 5        12177
# 15       12165
# 11       11586
# 19        8461
# 13        7728
# 18        6622
# 9         6291
# 8         1546

# %% [markdown]
#         Counting City_Category of dataset1

# %%
dataset1['City_Category'].value_counts()
# Out:
# B    231173
# C    171175
# A    147720
# Name: City_Category, dtype: int64

# %% [markdown]
#         Converting above series into dataframe

# %%
dataset1['City_Category'].value_counts().to_frame()
# Out:
#    City_Category
# B         231173
# C         171175
# A         147720

# %% [markdown]
#         Counting Stay_In_Current_City_Years of dataset1

# %%
dataset1['Stay_In_Current_City_Years'].value_counts()
# Out:
# 1     193821
# 2     101838
# 3      95285
# 4+     84726
# 0      74398
# Name: Stay_In_Current_City_Years, dtype: int64

# %% [markdown]
#         Converting above series into dataframe

# %%
dataset1['Stay_In_Current_City_Years'].value_counts().to_frame()
# Out:
#     Stay_In_Current_City_Years
# 1                       193821
# 2                       101838
# 3                        95285
# 4+                       84726
# 0                        74398

# %% [markdown]
#         Counting Marital_Status of dataset1

# %%
dataset1['Marital_Status'].value_counts()
# Out:
# 0    324731
# 1    225337
# Name: Marital_Status, dtype: int64

# %% [markdown]
#         Converting above series into dataframe

# %%
dataset1['Marital_Status'].value_counts().to_frame()
# Out:
#    Marital_Status
# 0          324731
# 1          225337

# %% [markdown]
#         Counting Product_Category_1 of dataset1

# %%
dataset1['Product_Category_1'].value_counts()
# Out:
# 5     150933
# 1     140378
# 8     113925
# 11     24287
# 2      23864
# 6      20466
# 3      20213
# 4      11753
# 16      9828
# 15      6290
# 13      5549
# 10      5125
# 12      3947
# 7       3721
# 18      3125
# 20      2550
# 19      1603
# 14      1523
# 17       578
# 9        410
# Name: Product_Category_1, dtype: int64

# %% [markdown]
#         Converting above series into dataframe

# %%
dataset1['Product_Category_1'].value_counts().to_frame()
# Out:
#     Product_Category_1
# 5               150933
# 1               140378
# 8               113925
# 11               24287
# 2                23864
# 6                20466
# 3                20213
# 4                11753
# 16                9828
# 15                6290
# 13                5549
# 10                5125
# 12                3947
# 7                 3721
# 18                3125
# 20                2550
# 19                1603
# 14                1523
# 17                 578
# 9                  410

# %% [markdown]
#         Counting Product_Category_2 of dataset1

# %%
dataset1['Product_Category_2'].value_counts()
# Out:
# 8.0     64088
# 14.0    55108
# 2.0     49217
# 16.0    43255
# 15.0    37855
# 5.0     26235
# 4.0     25677
# 6.0     16466
# 11.0    14134
# 17.0    13320
# 13.0    10531
# 9.0      5693
# 12.0     5528
# 10.0     3043
# 3.0      2884
# 18.0     2770
# 7.0       626
# Name: Product_Category_2, dtype: int64

# %% [markdown]
#         Converting above series into dataframe

# %%
dataset1['Product_Category_1'].value_counts().to_frame()
# Out:
#     Product_Category_1
# 5               150933
# 1               140378
# 8               113925
# 11               24287
# 2                23864
# 6                20466
# 3                20213
# 4                11753
# 16                9828
# 15                6290
# 13                5549
# 10                5125
# 12                3947
# 7                 3721
# 18                3125
# 20                2550
# 19                1603
# 14                1523
# 17                 578
# 9                  410

# %% [markdown]
#         Counting Product_Category_3 of dataset1

# %%
dataset1['Product_Category_3'].value_counts()
# Out:
# 16.0    32636
# 15.0    28013
# 14.0    18428
# 17.0    16702
# 5.0     16658
# 8.0     12562
# 9.0     11579
# 12.0     9246
# 13.0     5459
# 6.0      4890
# 18.0     4629
# 4.0      1875
# 11.0     1805
# 10.0     1726
# 3.0       613
# Name: Product_Category_3, dtype: int64

# %% [markdown]
#         Converting above series into dataframe

# %%
dataset1['Product_Category_1'].value_counts().to_frame()
# Out:
#     Product_Category_1
# 5               150933
# 1               140378
# 8               113925
# 11               24287
# 2                23864
# 6                20466
# 3                20213
# 4                11753
# 16                9828
# 15                6290
# 13                5549
# 10                5125
# 12                3947
# 7                 3721
# 18                3125
# 20                2550
# 19                1603
# 14                1523
# 17                 578
# 9                  410

# %% [markdown]
#         Counting Purchase of dataset1

# %%
dataset1['Purchase'].value_counts()
# Out:
# 7011     191
# 7193     188
# 6855     187
# 6891     184
# 7012     183
#         ...
# 23491      1
# 18345      1
# 3372       1
# 855        1
# 21489      1
# Name: Purchase, Length: 18105, dtype: int64

# %% [markdown]
#         Converting above series into dataframe

# %%
dataset1['Purchase'].value_counts().to_frame()
# Out:
#        Purchase
# 7011        191
# 7193        188
# 6855        187
# 6891        184
# 7012        183
# ...         ...
# 23491         1
# 18345         1
# 3372          1
# 855           1
# 21489         1
#
# [18105 rows x 1 columns]

# %% [markdown]
# # f) Describing the dataset2

# %% [markdown]
#         describe() funtion is only applied on integer and float values not on object datatype.

# %%
dataset2.describe()
# Out:
#             User_ID     Occupation  Marital_Status  Product_Category_1  \
# count  2.335990e+05  233599.000000   233599.000000       233599.000000
# mean   1.003029e+06       8.085407        0.410070            5.276542
# std    1.726505e+03       6.521146        0.491847            3.736380
# min    1.000001e+06       0.000000        0.000000            1.000000
# 25%    1.001527e+06       2.000000        0.000000            1.000000
# 50%    1.003070e+06       7.000000        0.000000            5.000000
# 75%    1.004477e+06      14.000000        1.000000            8.000000
# max    1.006040e+06      20.000000        1.000000           18.000000
#
#        Product_Category_2  Product_Category_3
# count       161255.000000        71037.000000
# mean             9.849586           12.669454
# std              5.094943            4.125944
# min              2.000000            3.000000
# 25%              5.000000            9.000000
# 50%              9.000000           14.000000
# ...

# %% [markdown]
#         To apply describe() function on object datatype we will write below command

# %%
dataset2.describe(include=['object'])
# Out:
#        Product_ID  Gender     Age City_Category Stay_In_Current_City_Years
# count      233599  233599  233599        233599                     233599
# unique       3491       2       7             3                          5
# top     P00265242       M   26-35             B                          1
# freq          829  175772   93428         98566                      82604

# %% [markdown]
# # g) Conting the values of dataset2

# %% [markdown]
#         Counting User_ID of dataset2

# %%
dataset2['User_ID'].value_counts()
# Out:
# 1001680    442
# 1004277    405
# 1001941    388
# 1000889    381
# 1001181    368
#           ...
# 1001226      1
# 1004943      1
# 1005207      1
# 1000665      1
# 1001189      1
# Name: User_ID, Length: 5891, dtype: int64

# %% [markdown]
#         Converting above series into dataframe

# %%
dataset2['User_ID'].value_counts().to_frame()
# Out:
#          User_ID
# 1001680      442
# 1004277      405
# 1001941      388
# 1000889      381
# 1001181      368
# ...          ...
# 1001226        1
# 1004943        1
# 1005207        1
# 1000665        1
# 1001189        1
#
# [5891 rows x 1 columns]

# %% [markdown]
#         Counting Product_ID of dataset2

# %%
dataset2['Product_ID'].value_counts()
# Out:
# P00265242    829
# P00112142    717
# P00025442    695
# P00110742    680
# P00046742    646
#             ...
# P00275042      1
# P00181042      1
# P00100242      1
# P00008942      1
# P00325442      1
# Name: Product_ID, Length: 3491, dtype: int64

# %% [markdown]
#         Converting above series into dataframe

# %%
dataset2['Product_ID'].value_counts().to_frame()
# Out:
#            Product_ID
# P00265242         829
# P00112142         717
# P00025442         695
# P00110742         680
# P00046742         646
# ...               ...
# P00275042           1
# P00181042           1
# P00100242           1
# P00008942           1
# P00325442           1
#
# [3491 rows x 1 columns]

# %% [markdown]
#         Counting Gender of dataset2

# %%
dataset2['Gender'].value_counts()
# Out:
# M    175772
# F     57827
# Name: Gender, dtype: int64

# %% [markdown]
#         Converting above series into dataframe

# %%
dataset2['Gender'].value_counts().to_frame()
# Out:
#    Gender
# M  175772
# F   57827

# %% [markdown]
#         Counting Age of dataset2

# %%
dataset2['Age'].value_counts()
# Out:
# 26-35    93428
# 36-45    46711
# 18-25    42293
# 46-50    19577
# 51-55    16283
# 55+       9075
# 0-17      6232
# Name: Age, dtype: int64

# %% [markdown]
#         Converting above series into dataframe

# %%
dataset2['Age'].value_counts().to_frame()
# Out:
#          Age
# 26-35  93428
# 36-45  46711
# 18-25  42293
# 46-50  19577
# 51-55  16283
# 55+     9075
# 0-17    6232

# %% [markdown]
#         Counting Occupation of dataset2

# %%
dataset2['Occupation'].value_counts()
# Out:
# 4     30778
# 0     29212
# 7     24994
# 1     20261
# 17    17375
# 20    14278
# 12    13269
# 14    11473
# 2     11408
# 16    10751
# 6      8747
# 3      7476
# 10     5374
# 5      5196
# 15     5191
# 11     5007
# 19     3458
# 13     3325
# 18     2745
# 9      2638
# 8       643
# Name: Occupation, dtype: int64

# %% [markdown]
#         Converting above series into dataframe

# %%
dataset2['Occupation'].value_counts().to_frame()
# Out:
#     Occupation
# 4        30778
# 0        29212
# 7        24994
# 1        20261
# 17       17375
# 20       14278
# 12       13269
# 14       11473
# 2        11408
# 16       10751
# 6         8747
# 3         7476
# 10        5374
# 5         5196
# 15        5191
# 11        5007
# 19        3458
# 13        3325
# 18        2745
# 9         2638
# 8          643

# %% [markdown]
#         Counting City_Category of dataset2

# %%
dataset2['City_Category'].value_counts()
# Out:
# B    98566
# C    72509
# A    62524
# Name: City_Category, dtype: int64

# %% [markdown]
#         Converting above series into dataframe

# %%
dataset2['City_Category'].value_counts().to_frame()
# Out:
#    City_Category
# B          98566
# C          72509
# A          62524

# %% [markdown]
#         Counting Stay_In_Current_City_Years of dataset2

# %%
dataset2['Stay_In_Current_City_Years'].value_counts()
# Out:
# 1     82604
# 2     43589
# 3     40143
# 4+    35945
# 0     31318
# Name: Stay_In_Current_City_Years, dtype: int64

# %% [markdown]
#         Converting above series into dataframe

# %%
dataset2['Stay_In_Current_City_Years'].value_counts().to_frame()
# Out:
#     Stay_In_Current_City_Years
# 1                        82604
# 2                        43589
# 3                        40143
# 4+                       35945
# 0                        31318

# %% [markdown]
#         Counting Marital_Status of dataset2

# %%
dataset2['Marital_Status'].value_counts()
# Out:
# 0    137807
# 1     95792
# Name: Marital_Status, dtype: int64

# %% [markdown]
#         Converting above series into dataframe

# %%
dataset2['Marital_Status'].value_counts().to_frame()
# Out:
#    Marital_Status
# 0          137807
# 1           95792

# %% [markdown]
#         Counting Product_Category_1 of dataset2

# %%
dataset2['Product_Category_1'].value_counts()
# Out:
# 5     65017
# 1     60321
# 8     48369
# 2     10192
# 11    10153
# 6      8860
# 3      8578
# 4      5003
# 16     4105
# 15     2694
# 13     2381
# 10     2248
# 12     1663
# 7      1624
# 18     1311
# 14      663
# 17      223
# 9       194
# Name: Product_Category_1, dtype: int64

# %% [markdown]
#         Converting above series into dataframe

# %%
dataset2['Product_Category_1'].value_counts().to_frame()
# Out:
#     Product_Category_1
# 5                65017
# 1                60321
# 8                48369
# 2                10192
# 11               10153
# 6                 8860
# 3                 8578
# 4                 5003
# 16                4105
# 15                2694
# 13                2381
# 10                2248
# 12                1663
# 7                 1624
# 18                1311
# 14                 663
# 17                 223
# 9                  194

# %% [markdown]
#         Counting Product_Category_2 of dataset2

# %%
dataset2['Product_Category_2'].value_counts()
# Out:
# 8.0     27229
# 14.0    23726
# 2.0     21281
# 16.0    18432
# 15.0    16259
# 4.0     11028
# 5.0     10930
# 6.0      7109
# 11.0     6096
# 17.0     5784
# 13.0     4523
# 9.0      2484
# 12.0     2273
# 10.0     1377
# 18.0     1257
# 3.0      1239
# 7.0       228
# Name: Product_Category_2, dtype: int64

# %% [markdown]
#         Converting above series into dataframe

# %%
dataset2['Product_Category_2'].value_counts().to_frame()
# Out:
#       Product_Category_2
# 8.0                27229
# 14.0               23726
# 2.0                21281
# 16.0               18432
# 15.0               16259
# 4.0                11028
# 5.0                10930
# 6.0                 7109
# 11.0                6096
# 17.0                5784
# 13.0                4523
# 9.0                 2484
# 12.0                2273
# 10.0                1377
# 18.0                1257
# 3.0                 1239
# 7.0                  228

# %% [markdown]
#         Counting Product_Category_3 of dataset2

# %%
dataset2['Product_Category_3'].value_counts()
# Out:
# 16.0    13833
# 15.0    11955
# 14.0     7855
# 5.0      7141
# 17.0     7116
# 8.0      5299
# 9.0      4953
# 12.0     3869
# 13.0     2390
# 6.0      1998
# 18.0     1992
# 4.0       816
# 11.0      780
# 10.0      775
# 3.0       265
# Name: Product_Category_3, dtype: int64

# %% [markdown]
#         Converting above series into dataframe

# %%
dataset2['Product_Category_3'].value_counts().to_frame()
# Out:
#       Product_Category_3
# 16.0               13833
# 15.0               11955
# 14.0                7855
# 5.0                 7141
# 17.0                7116
# 8.0                 5299
# 9.0                 4953
# 12.0                3869
# 13.0                2390
# 6.0                 1998
# 18.0                1992
# 4.0                  816
# 11.0                 780
# 10.0                 775
# 3.0                  265

# %% [markdown]
# # 2. Check for missing values in the dataset1 and dataset2

# %% [markdown]
#     The following command is checking is there any value which is null or mising in both the datasets(csv files), and by any() we'll get a boolean return as true or false

# %%
print("Any missing values in Dataset1 ?",dataset1.isnull().values.any())
# Out:
# Any missing values in Dataset1 ? True

# %%
print("Any missing values in Dataset2 ?",dataset2.isnull().values.any())
# Out:
# Any missing values in Dataset2 ? True

# %% [markdown]
#         Below code is to find null data in the dataset1 and dataset2

# %%
dataset1.isnull()
# Out:
#         User_ID  Product_ID  Gender    Age  Occupation  City_Category  \
# 0         False       False   False  False       False          False
# 1         False       False   False  False       False          False
# 2         False       False   False  False       False          False
# 3         False       False   False  False       False          False
# 4         False       False   False  False       False          False
# ...         ...         ...     ...    ...         ...            ...
# 550063    False       False   False  False       False          False
# 550064    False       False   False  False       False          False
# 550065    False       False   False  False       False          False
# 550066    False       False   False  False       False          False
# 550067    False       False   False  False       False          False
#
#         Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# ...

# %%
dataset2.isnull()
# Out:
#         User_ID  Product_ID  Gender    Age  Occupation  City_Category  \
# 0         False       False   False  False       False          False
# 1         False       False   False  False       False          False
# 2         False       False   False  False       False          False
# 3         False       False   False  False       False          False
# 4         False       False   False  False       False          False
# ...         ...         ...     ...    ...         ...            ...
# 233594    False       False   False  False       False          False
# 233595    False       False   False  False       False          False
# 233596    False       False   False  False       False          False
# 233597    False       False   False  False       False          False
# 233598    False       False   False  False       False          False
#
#         Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# ...

# %% [markdown]
#         Finding the total data that are having null values with the help of sum() function

# %%
dataset1.isnull().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            173638
# Product_Category_3            383247
# Purchase                           0
# dtype: int64

# %%
dataset2.isnull().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2             72344
# Product_Category_3            162562
# dtype: int64

# %% [markdown]
# # Visualizing the data for all individual columns

# %% [markdown]
#     sns.heatmap() function let us plot of rectangular data as a color-encoded matrix as a visual representation of dataset
#     for null values in data

# %%
sns.heatmap(dataset1.isnull())
# Out:
# <Axes: >

# %%
sns.heatmap(dataset2.isnull())
# Out:
# <Axes: >

# %% [markdown]
# # Finding missing values in percentage

# %% [markdown]
#     The following code is for finding the percentage of null values in the complete data given to us in each datasets

# %%
Missing1 = dataset1.isnull().sum()*100/len(dataset1)
Missing1
# Out:
# User_ID                        0.000000
# Product_ID                     0.000000
# Gender                         0.000000
# Age                            0.000000
# Occupation                     0.000000
# City_Category                  0.000000
# Stay_In_Current_City_Years     0.000000
# Marital_Status                 0.000000
# Product_Category_1             0.000000
# Product_Category_2            31.566643
# Product_Category_3            69.672659
# Purchase                       0.000000
# dtype: float64

# %%
Missing2 = dataset2.isnull().sum()*100/len(dataset2)
Missing2
# Out:
# User_ID                        0.000000
# Product_ID                     0.000000
# Gender                         0.000000
# Age                            0.000000
# Occupation                     0.000000
# City_Category                  0.000000
# Stay_In_Current_City_Years     0.000000
# Marital_Status                 0.000000
# Product_Category_1             0.000000
# Product_Category_2            30.969311
# Product_Category_3            69.590195
# dtype: float64

# %% [markdown]
# # Checking for unique values in the dataset1 and dataset2

# %% [markdown]
#     nunique() function is used to calculate the overall unique values in the data given to us, by checking arrays of data
#     and showing the complete sum of it like below

# %%
dataset1.nunique()
# Out:
# User_ID                        5891
# Product_ID                     3631
# Gender                            2
# Age                               7
# Occupation                       21
# City_Category                     3
# Stay_In_Current_City_Years        5
# Marital_Status                    2
# Product_Category_1               20
# Product_Category_2               17
# Product_Category_3               15
# Purchase                      18105
# dtype: int64

# %%
dataset2.nunique()
# Out:
# User_ID                       5891
# Product_ID                    3491
# Gender                           2
# Age                              7
# Occupation                      21
# City_Category                    3
# Stay_In_Current_City_Years       5
# Marital_Status                   2
# Product_Category_1              18
# Product_Category_2              17
# Product_Category_3              15
# dtype: int64

# %% [markdown]
#     unique() function will let us get the unique data in particular columns of the data in array form

# %%
dataset1['User_ID'].unique()
# Out:
# array([1000001, 1000002, 1000003, ..., 1004113, 1005391, 1001529],
#       dtype=int64)

# %%
dataset2['User_ID'].unique()
# Out:
# array([1000004, 1000009, 1000010, ..., 1001656, 1005796, 1001189],
#       dtype=int64)

# %%
dataset1['Product_ID'].unique()
# Out:
# array(['P00069042', 'P00248942', 'P00087842', ..., 'P00370293',
#        'P00371644', 'P00370853'], dtype=object)

# %%
dataset2['Product_ID'].unique()
# Out:
# array(['P00128942', 'P00113442', 'P00288442', ..., 'P00270742',
#        'P00253842', 'P00325442'], dtype=object)

# %%
dataset1['Gender'].unique()
# Out:
# array(['F', 'M'], dtype=object)

# %%
dataset2['Gender'].unique()
# Out:
# array(['M', 'F'], dtype=object)

# %%
dataset1['Age'].unique()
# Out:
# array(['0-17', '55+', '26-35', '46-50', '51-55', '36-45', '18-25'],
#       dtype=object)

# %%
dataset2['Age'].unique()
# Out:
# array(['46-50', '26-35', '36-45', '18-25', '51-55', '55+', '0-17'],
#       dtype=object)

# %%
dataset1['Occupation'].unique()
# Out:
# array([10, 16, 15,  7, 20,  9,  1, 12, 17,  0,  3,  4, 11,  8, 19,  2, 18,
#         5, 14, 13,  6], dtype=int64)

# %%
dataset2['Occupation'].unique()
# Out:
# array([ 7, 17,  1, 15,  3,  0,  8, 16,  4, 12, 13, 18, 11,  9,  2, 20, 14,
#        10,  6, 19,  5], dtype=int64)

# %%
dataset1['City_Category'].unique()
# Out:
# array(['A', 'C', 'B'], dtype=object)

# %%
dataset2['City_Category'].unique()
# Out:
# array(['B', 'C', 'A'], dtype=object)

# %%
dataset1['Stay_In_Current_City_Years'].unique()
# Out:
# array(['2', '4+', '3', '1', '0'], dtype=object)

# %%
dataset2['Stay_In_Current_City_Years'].unique()
# Out:
# array(['2', '0', '4+', '1', '3'], dtype=object)

# %%
dataset1['Marital_Status'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
dataset2['Marital_Status'].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
dataset1['Product_Category_1'].unique()
# Out:
# array([ 3,  1, 12,  8,  5,  4,  2,  6, 14, 11, 13, 15,  7, 16, 18, 10, 17,
#         9, 20, 19], dtype=int64)

# %%
dataset2['Product_Category_1'].unique()
# Out:
# array([ 1,  3,  5,  4,  2, 10, 15, 18,  8, 13,  6, 11, 12,  7, 16, 14, 17,
#         9], dtype=int64)

# %%
dataset1['Product_Category_2'].unique()
# Out:
# array([nan,  6., 14.,  2.,  8., 15., 16., 11.,  5.,  3.,  4., 12.,  9.,
#        10., 17., 13.,  7., 18.])

# %%
dataset2['Product_Category_2'].unique()
# Out:
# array([11.,  5., 14.,  9.,  3.,  4., 13.,  2., nan,  8., 15., 17., 12.,
#        16.,  6., 10., 18.,  7.])

# %%
dataset1['Product_Category_3'].unique()
# Out:
# array([nan, 14., 17.,  5.,  4., 16., 15.,  8.,  9., 13.,  6., 12.,  3.,
#        18., 11., 10.])

# %%
dataset2['Product_Category_3'].unique()
# Out:
# array([nan, 12., 15.,  9., 16., 14.,  4.,  3.,  5.,  8., 17., 13., 11.,
#        10.,  6., 18.])

# %%
dataset1['Purchase'].unique()
# Out:
# array([ 8370, 15200,  1422, ...,   135,   123,   613], dtype=int64)

# %% [markdown]
# # Perform EDA

# %% [markdown]
#         For performing EDA we have to mainly focus on 3 things which are:
#             1. Reading/Understand the data (which I have done before)
#             2. Cleaning unwanted data
#             3. Relationship Analysis between variables

# %%
clean1 = dataset1.drop(['Stay_In_Current_City_Years','Marital_Status'],axis=1)

# %% [markdown]
#     In the above statement drop() function is letting us delete the columns which are not so important from data for further
#     and more deep analyis of data
#     In the below statement head() function will show us the first 5 data (By default head() function show first 5 data,
#     if we want to show more data then we need to pass the argument for example head(10) This will show first 10 data)

# %%
clean1.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#    Product_Category_1  Product_Category_2  Product_Category_3  Purchase
# 0                   3                 NaN                 NaN      8370
# 1                   1                 6.0                14.0     15200
# 2                  12                 NaN                 NaN      1422
# 3                  12                14.0                 NaN      1057
# 4                   8                 NaN                 NaN      7969

# %%
clean2 = dataset2.drop(['Stay_In_Current_City_Years','Marital_Status'],axis=1)

# %%
clean2.head()
# Out:
#    User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0  1000004  P00128942      M  46-50           7             B
# 1  1000009  P00113442      M  26-35          17             C
# 2  1000010  P00288442      F  36-45           1             B
# 3  1000010  P00145342      F  36-45           1             B
# 4  1000011  P00053842      F  26-35           1             C
#
#    Product_Category_1  Product_Category_2  Product_Category_3
# 0                   1                11.0                 NaN
# 1                   3                 5.0                 NaN
# 2                   5                14.0                 NaN
# 3                   4                 9.0                 NaN
# 4                   4                 5.0                12.0

# %% [markdown]
#     corr() function is used to create pairwise correlation between all the columns in the dataset, and if null value is
#     present, it will be excluded automatically.

# %%
corelation = dataset1.corr()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_4484\2610957123.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corelation = dataset1.corr()

# %%
sns.heatmap(corelation, xticklabels=corelation.columns, yticklabels=corelation.columns, annot=True)
# Out:
# <Axes: >

# %% [markdown]
#     sns.pairplot() lets us to plot relationships between variables within the dataset.

# %%
sns.pairplot(clean1)

# %%
sns.pairplot(clean2)

# %% [markdown]
#     sns.relplot() function means Seaborn Relational Plot
#     replot() allows us to visualize how variables within a dataset relate to each other.

# %%
sns.relplot(x='Age', y='Product_Category_1', hue='Gender', data=clean2)

# %%
sns.relplot(x='Age', y='Product_Category_2', hue='Gender', data=clean1)

# %%
sns.relplot(x='Age', y='Product_Category_2', hue='Gender', data=clean2)

# %%
sns.relplot(x='Age', y='Product_Category_3', hue='Gender', data=clean1)

# %%
sns.relplot(x='Age', y='Product_Category_3', hue='Gender', data=clean2)

# %% [markdown]
#     sns.displot() function that provides us access to several approached for visualizing univariate and bivariate
#     distribution of data.

# %%
sns.displot(clean1['Product_Category_1'])

# %%
sns.displot(clean2['Product_Category_1'])

# %%
sns.displot(clean1['Product_Category_2'])

# %%
sns.displot(clean2['Product_Category_2'])

# %%
sns.displot(clean1['Product_Category_3'])

# %%
sns.displot(clean2['Product_Category_3'])

# %% [markdown]
# # Check for outliers

# %% [markdown]
#     sns.boxplot() function is used to visualize distribution and is very useful when we have to compare data between two
#     groups.

# %%
sns.boxplot(x='Product_Category_1', y='Product_Category_2', data= clean1)
# Out:
# <Axes: xlabel='Product_Category_1', ylabel='Product_Category_2'>

# %%
sns.boxplot(x='Product_Category_1', y='Product_Category_2', data= clean2)
# Out:
# <Axes: xlabel='Product_Category_1', ylabel='Product_Category_2'>

# %% [markdown]
# # Drop unnessecary fields

# %% [markdown]
#         In the above process of EDA
#         we've dropped two unnessecary fields from dataset1 and dataset2 as clean1 and clean2 respectively.

# %%
clean1
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 550063  1006033  P00372445      M  51-55          13             B
# 550064  1006035  P00375436      F  26-35           1             C
# 550065  1006036  P00375436      F  26-35          15             B
# 550066  1006038  P00375436      F    55+           1             C
# 550067  1006039  P00371644      F  46-50           0             B
#
#         Product_Category_1  Product_Category_2  Product_Category_3  Purchase
# 0                        3                 NaN                 NaN      8370
# ...

# %%
clean2
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000004  P00128942      M  46-50           7             B
# 1       1000009  P00113442      M  26-35          17             C
# 2       1000010  P00288442      F  36-45           1             B
# 3       1000010  P00145342      F  36-45           1             B
# 4       1000011  P00053842      F  26-35           1             C
# ...         ...        ...    ...    ...         ...           ...
# 233594  1006036  P00118942      F  26-35          15             B
# 233595  1006036  P00254642      F  26-35          15             B
# 233596  1006036  P00031842      F  26-35          15             B
# 233597  1006037  P00124742      F  46-50           1             C
# 233598  1006039  P00316642      F  46-50           0             B
#
#         Product_Category_1  Product_Category_2  Product_Category_3
# 0                        1                11.0                 NaN
# ...

# %% [markdown]
# # Convert categorical data into integer using map function

# %% [markdown]
#         For dataset1

# %% [markdown]
#     In the below statement we're facotrizing the data and creating a categorical data or string type into integer type (int)
#     for better consideration of Gender in graphs by using factorize() function.

# %%
dataset1['Gen'] = pd.factorize(dataset1.Gender)[0]

# %%
dataset1.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase  Gen
# 0                 NaN                 NaN      8370    0
# 1                 6.0                14.0     15200    0
# ...

# %% [markdown]
#     In the below statement tail() function will show us the last 5 data (By default tail() function show last 5 data,
#     if we want to show more data then we need to pass the argument for example tail(10) This will show last 10 data)

# %%
dataset1.tail()
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 550063  1006033  P00372445      M  51-55          13             B
# 550064  1006035  P00375436      F  26-35           1             C
# 550065  1006036  P00375436      F  26-35          15             B
# 550066  1006038  P00375436      F    55+           1             C
# 550067  1006039  P00371644      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 550063                          1               1                  20
# 550064                          3               0                  20
# 550065                         4+               1                  20
# 550066                          2               0                  20
# 550067                         4+               1                  20
#
#         Product_Category_2  Product_Category_3  Purchase  Gen
# 550063                 NaN                 NaN       368    1
# ...

# %%
dataset1.Gender.value_counts()
# Out:
# M    414259
# F    135809
# Name: Gender, dtype: int64

# %%
dataset1.Gen.value_counts()
# Out:
# 1    414259
# 0    135809
# Name: Gen, dtype: int64

# %% [markdown]
#         For dataset2

# %%
dataset2['Gen'] = pd.factorize(dataset2.Gender)[0]

# %%
dataset2.head()
# Out:
#    User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0  1000004  P00128942      M  46-50           7             B
# 1  1000009  P00113442      M  26-35          17             C
# 2  1000010  P00288442      F  36-45           1             B
# 3  1000010  P00145342      F  36-45           1             B
# 4  1000011  P00053842      F  26-35           1             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               1                   1
# 1                          0               0                   3
# 2                         4+               1                   5
# 3                         4+               1                   4
# 4                          1               0                   4
#
#    Product_Category_2  Product_Category_3  Gen
# 0                11.0                 NaN    0
# 1                 5.0                 NaN    0
# 2                14.0                 NaN    1
# ...

# %%
dataset2.tail()
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 233594  1006036  P00118942      F  26-35          15             B
# 233595  1006036  P00254642      F  26-35          15             B
# 233596  1006036  P00031842      F  26-35          15             B
# 233597  1006037  P00124742      F  46-50           1             C
# 233598  1006039  P00316642      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 233594                         4+               1                   8
# 233595                         4+               1                   5
# 233596                         4+               1                   1
# 233597                         4+               0                  10
# 233598                         4+               1                   4
#
#         Product_Category_2  Product_Category_3  Gen
# 233594                 NaN                 NaN    1
# ...

# %%
dataset2.Gender.value_counts()
# Out:
# M    175772
# F     57827
# Name: Gender, dtype: int64

# %%
dataset2.Gen.value_counts()
# Out:
# 0    175772
# 1     57827
# Name: Gen, dtype: int64

# %% [markdown]
# # Missing value treatment and Filling the Null Values

# %%
dataset1.isnull()
# Out:
#         User_ID  Product_ID  Gender    Age  Occupation  City_Category  \
# 0         False       False   False  False       False          False
# 1         False       False   False  False       False          False
# 2         False       False   False  False       False          False
# 3         False       False   False  False       False          False
# 4         False       False   False  False       False          False
# ...         ...         ...     ...    ...         ...            ...
# 550063    False       False   False  False       False          False
# 550064    False       False   False  False       False          False
# 550065    False       False   False  False       False          False
# 550066    False       False   False  False       False          False
# 550067    False       False   False  False       False          False
#
#         Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# ...

# %%
dataset2.isnull()
# Out:
#         User_ID  Product_ID  Gender    Age  Occupation  City_Category  \
# 0         False       False   False  False       False          False
# 1         False       False   False  False       False          False
# 2         False       False   False  False       False          False
# 3         False       False   False  False       False          False
# 4         False       False   False  False       False          False
# ...         ...         ...     ...    ...         ...            ...
# 233594    False       False   False  False       False          False
# 233595    False       False   False  False       False          False
# 233596    False       False   False  False       False          False
# 233597    False       False   False  False       False          False
# 233598    False       False   False  False       False          False
#
#         Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# ...

# %%
dataset1.isnull().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            173638
# Product_Category_3            383247
# Purchase                           0
# Gen                                0
# dtype: int64

# %% [markdown]
#         For Total null values in dataset1

# %%
dataset1.isnull().sum().sum()
# Out:
# 556885

# %%
dataset2.isnull().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2             72344
# Product_Category_3            162562
# Gen                                0
# dtype: int64

# %% [markdown]
#         For Total null values in dataset2

# %%
dataset2.isnull().sum().sum()
# Out:
# 234906

# %% [markdown]
#         Filling the Null values

# %% [markdown]
#     In the below statement we're using fillna() function to fill the null values by putting value 'N/A' in the dataset.

# %%
fill1 = dataset1.fillna(value = 'N/A')

# %%
fill1
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 550063  1006033  P00372445      M  51-55          13             B
# 550064  1006035  P00375436      F  26-35           1             C
# 550065  1006036  P00375436      F  26-35          15             B
# 550066  1006038  P00375436      F    55+           1             C
# 550067  1006039  P00371644      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %%
fill1.isnull().sum()
# Out:
# User_ID                       0
# Product_ID                    0
# Gender                        0
# Age                           0
# Occupation                    0
# City_Category                 0
# Stay_In_Current_City_Years    0
# Marital_Status                0
# Product_Category_1            0
# Product_Category_2            0
# Product_Category_3            0
# Purchase                      0
# Gen                           0
# dtype: int64

# %%
fill2 = dataset2.fillna(value="N/A")

# %%
fill2
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000004  P00128942      M  46-50           7             B
# 1       1000009  P00113442      M  26-35          17             C
# 2       1000010  P00288442      F  36-45           1             B
# 3       1000010  P00145342      F  36-45           1             B
# 4       1000011  P00053842      F  26-35           1             C
# ...         ...        ...    ...    ...         ...           ...
# 233594  1006036  P00118942      F  26-35          15             B
# 233595  1006036  P00254642      F  26-35          15             B
# 233596  1006036  P00031842      F  26-35          15             B
# 233597  1006037  P00124742      F  46-50           1             C
# 233598  1006039  P00316642      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               1                   1
# ...

# %%
fill2.isnull().sum()
# Out:
# User_ID                       0
# Product_ID                    0
# Gender                        0
# Age                           0
# Occupation                    0
# City_Category                 0
# Stay_In_Current_City_Years    0
# Marital_Status                0
# Product_Category_1            0
# Product_Category_2            0
# Product_Category_3            0
# Gen                           0
# dtype: int64

# %% [markdown]
# # Rename columns for dataset1

# %%
rename1 = dataset1.rename(columns={'Product_Category_1':'P_1','Product_Category_2':'P_2','Product_Category_3':'P_3'})

# %%
rename1
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 550063  1006033  P00372445      M  51-55          13             B
# 550064  1006035  P00375436      F  26-35           1             C
# 550065  1006036  P00375436      F  26-35          15             B
# 550066  1006038  P00375436      F    55+           1             C
# 550067  1006039  P00371644      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  P_1   P_2   P_3  Purchase  \
# 0                               2               0    3   NaN   NaN      8370
# ...

# %% [markdown]
# # Rename columns for dataset2

# %%
rename2 = dataset2.rename(columns={'Product_Category_1':'P_1','Product_Category_2':'P_2','Product_Category_3':'P_3','Stay_In_Current_City_Years':'In_City_From'})
rename2
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000004  P00128942      M  46-50           7             B
# 1       1000009  P00113442      M  26-35          17             C
# 2       1000010  P00288442      F  36-45           1             B
# 3       1000010  P00145342      F  36-45           1             B
# 4       1000011  P00053842      F  26-35           1             C
# ...         ...        ...    ...    ...         ...           ...
# 233594  1006036  P00118942      F  26-35          15             B
# 233595  1006036  P00254642      F  26-35          15             B
# 233596  1006036  P00031842      F  26-35          15             B
# 233597  1006037  P00124742      F  46-50           1             C
# 233598  1006039  P00316642      F  46-50           0             B
#
#        In_City_From  Marital_Status  P_1   P_2   P_3  Gen
# 0                 2               1    1  11.0   NaN    0
# ...

# %% [markdown]
# # Map range variables into integers

# %%
dataset1['Age_Code'] = pd.factorize(dataset1.Age)[0]
dataset1.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase  Gen  Age_Code
# 0                 NaN                 NaN      8370    0         0
# 1                 6.0                14.0     15200    0         0
# ...

# %%
dataset2['Age_Code'] = pd.factorize(dataset2.Age)[0]
dataset2.head()
# Out:
#    User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0  1000004  P00128942      M  46-50           7             B
# 1  1000009  P00113442      M  26-35          17             C
# 2  1000010  P00288442      F  36-45           1             B
# 3  1000010  P00145342      F  36-45           1             B
# 4  1000011  P00053842      F  26-35           1             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               1                   1
# 1                          0               0                   3
# 2                         4+               1                   5
# 3                         4+               1                   4
# 4                          1               0                   4
#
#    Product_Category_2  Product_Category_3  Gen  Age_Code
# 0                11.0                 NaN    0         0
# 1                 5.0                 NaN    0         1
# ...

# %% [markdown]
# # Data Visualization

# %% [markdown]
# # Visualize an Individual Columns

# %% [markdown]
#     sns.countplot() function is used to display the count of categorical distributions of each column in the given dataset.
#     plt.title() function is used to give title to the graph we're representing.
#     plt.show() function is used to show the graph.

# %%
sns.countplot(x='User_ID',data=dataset1)
plt.title("Viualizing User_ID for dataset1")
plt.show()

# %%
sns.countplot(x='User_ID',data=dataset2)
plt.title("Viualizing User_ID for dataset2")
plt.show()

# %%
sns.countplot(x='Product_ID',data=dataset1)
plt.title("Viualizing Product_ID for dataset1")
plt.show()

# %%
sns.countplot(x='Product_ID',data=dataset2)
plt.title("Viualizing Product_ID for dataset2")
plt.show()

# %%
sns.countplot(x='Gender',data=dataset1)
plt.title("Viualizing Gender for dataset1")
plt.show()

# %%
sns.countplot(x='Gender',data=dataset2)
plt.title("Viualizing Gender for dataset2")
plt.show()

# %%
sns.countplot(x='Age',data=dataset1)
plt.title("Viualizing Age for dataset1")
plt.show()

# %%
sns.countplot(x='Age',data=dataset2)
plt.title("Viualizing Age for dataset2")
plt.show()

# %%
sns.countplot(x='Occupation',data=dataset1)
plt.title("Viualizing Occupation for dataset1")
plt.show()

# %%
sns.countplot(x='Occupation',data=dataset2)
plt.title("Viualizing Occupation for dataset2")
plt.show()

# %%
sns.countplot(x='City_Category',data=dataset1)
plt.title("Viualizing City_Category for dataset1")
plt.show()

# %%
sns.countplot(x='City_Category',data=dataset2)
plt.title("Viualizing City_Category for dataset2")
plt.show()

# %%
sns.countplot(x='Stay_In_Current_City_Years',data=dataset1)
plt.title("Viualizing Stay_In_Current_City_Years for dataset1")
plt.show()

# %%
sns.countplot(x='Stay_In_Current_City_Years',data=dataset2)
plt.title("Viualizing Stay_In_Current_City_Years for dataset2")
plt.show()

# %%
sns.countplot(x='Marital_Status',data=dataset1)
plt.title("Viualizing Marital_Status for dataset1")
plt.show()

# %%
sns.countplot(x='Marital_Status',data=dataset2)
plt.title("Viualizing Marital_Status for dataset2")
plt.show()

# %%
sns.countplot(x='Product_Category_1',data=dataset1)
plt.title("Viualizing Product_Category_1 for dataset1")
plt.show()

# %%
sns.countplot(x='Product_Category_1',data=dataset2)
plt.title("Viualizing Product_Category_1 for dataset2")
plt.show()

# %%
sns.countplot(x='Product_Category_2',data=dataset1)
plt.title("Viualizing Product_Category_2 for dataset1")
plt.show()

# %%
sns.countplot(x='Product_Category_2',data=dataset2)
plt.title("Viualizing Product_Category_1 for dataset2")
plt.show()

# %%
sns.countplot(x='Product_Category_3',data=dataset1)
plt.title("Viualizing Product_Category_1 for dataset1")
plt.show()

# %%
sns.countplot(x='Product_Category_3',data=dataset2)
plt.title("Viualizing Product_Category_1 for dataset2")
plt.show()

# %%
sns.countplot(x='Purchase',data=dataset1)
plt.title("Viualizing Purchase for dataset1")
plt.show()

# %% [markdown]
# # Age v/s Purchased

# %%
x= dataset1['Age']
y= dataset1['Purchase']

# %% [markdown]
#         In the above statement we're storing the dataset1 Age and Purchase columns respectively in x and y.
#
#         In the below statement xlabel() function in pyplot module of matplotlib library is used to set the label for x-axis
#         and ylabel() function in pyplot module of matplotlib library is used to set the label for y-axis.
#         and plt.bar() function is used to plot bar graph for the above labels we declared.

# %%
plt.xlabel('Age',fontsize=18)
plt.ylabel('Purchase',fontsize=18)
plt.bar(x,y)
# Out:
# <BarContainer object of 550068 artists>

# %%
plt.show()

# %% [markdown]
# # Occupation v/s Purchased

# %%
x= dataset1['Occupation']
y= dataset1['Purchase']
plt.xlabel('Occupation',fontsize=18)
plt.ylabel('Purchase',fontsize=18)
plt.bar(x,y)
# Out:
# <BarContainer object of 550068 artists>

# %% [markdown]
# # Product_Category_1 v/s Purchased

# %%
x= dataset1['Product_Category_1']
y= dataset1['Purchase']
plt.xlabel('Product_Category_1',fontsize=18)
plt.ylabel('Purchase',fontsize=18)
plt.bar(x,y)
# Out:
# <BarContainer object of 550068 artists>

# %% [markdown]
# # Product_Category_2 v/s Purchased

# %%
x= dataset1['Product_Category_2']
y= dataset1['Purchase']
plt.xlabel('Product_Category_2',fontsize=18)
plt.ylabel('Purchase',fontsize=18)
plt.bar(x,y)
# Out:
# <BarContainer object of 550068 artists>

# %% [markdown]
# # Product_Category_3 v/s Purchased

# %%
x= dataset1['Product_Category_3']
y= dataset1['Purchase']
plt.xlabel('Product_Category_3',fontsize=18)
plt.ylabel('Purchase',fontsize=18)
plt.bar(x,y)
# Out:
# <BarContainer object of 550068 artists>

# %% [markdown]
# # City Category Pie Chart

# %%
dataset1['City'] = pd.factorize(dataset1.City_Category)[0]
dataset1.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase  City
# 0                 NaN                 NaN      8370     0
# 1                 6.0                14.0     15200     0
# ...

# %% [markdown]
#     pie() function generates pie graph representing data in an array which we convert from string type to int type in the above
#     command and used it in groupby for analysing it with string data for pie graph.
#     axis is a function of the matplotlib library that adds axis to the current graph and makes it as current axis.

# %%
sums = dataset1.groupby(dataset1["City_Category"])["City"].sum()
axis('equal');
pie(sums,labels=sums.index);
show()
